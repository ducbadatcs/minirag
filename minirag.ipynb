# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBmD7z5uWUA5lCGZCvyDhL9bqgXpziZXGY"

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

llm.invoke("test").content
# Out:
# "This is a successful test.  I'm ready for your next instruction.\n"

# %%
import pandas as pd
df = pd.read_csv("./pg_catalog.csv")
from datetime import datetime

df["Issued"] = df["Issued"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d"))
df
# Out:
#        Text#  Type     Issued  \
# 0          1  Text 1971-12-01
# 1          2  Text 1972-12-01
# 2          3  Text 1973-11-01
# 3          4  Text 1973-11-01
# 4          5  Text 1975-12-01
# ...      ...   ...        ...
# 74614  74789  Text 2024-11-24
# 74615  74790  Text 2024-11-24
# 74616  74791  Text 2024-11-24
# 74617  74792  Text 2024-11-24
# 74618  90907  Text 2019-12-12
#
#                                                    Title Language  \
# 0      The Declaration of Independence of the United ...       en
# 1      The United States Bill of Rights\r\nThe Ten Or...       en
# 2                    John F. Kennedy's Inaugural Address       en
# 3      Lincoln's Gettysburg Address\r\nGiven November...       en
# 4                         The United States Constitution       en
# ...                                                  ...      ...
# 74614                              La fortune de Fortuné       fr
# ...

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///Chinook.db")
print(db.dialect)
print(db.get_usable_table_names())
db.run("SELECT * FROM Artist LIMIT 10;")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 5
#       2 from langchain.tools import tool
#       3 import sqlite3
# ----> 5 @tool
#       6 def query_dataset(type: str, title: str, language: str, author: str, s) -> bool:
#       7     return False
#
# File c:\Users\minhduc\Documents\minirag\Lib\site-packages\langchain_core\tools\convert.py:304, in tool(name_or_callable, runnable, return_direct, args_schema, infer_schema, response_format, parse_docstring, error_on_invalid_docstring, *args)
#     298 elif name_or_callable is not None:
#     299     if callable(name_or_callable) and hasattr(name_or_callable, "__name__"):
#     300         # Used as a decorator without parameters
#     301         # @tool
#     302         # def my_tool():
#     303         #    pass
# --> 304         return _create_tool_factory(name_or_callable.__name__)(name_or_callable)
# ...

# %%
import datetime

x = datetime.date(1970, 1, 1).year

y = datetime.date(1975, 4, 30)

x
# Out:
# 1970
